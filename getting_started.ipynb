# %%
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/rocm5.6 (https://pytorch.org/get-started/locally/)

# %%
# https://github.com/ultralytics/ultralytics (read README.md)

# %%
# !yolo predict model=yolov8l.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100%|██████████████████████████████████████| 83.7M/83.7M [00:01<00:00, 74.5MB/s]
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.2+rocm5.6 CUDA:0 (AMD Radeon RX 6700 XT, 12272MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/mentefria/Documents/YOLO_retraining/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 414.7ms
# Speed: 3.1ms preprocess, 414.7ms inference, 95.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image(filename='bus.jpg')

# %%
Image(filename="runs/detect/predict/bus.jpg")

# %%
from ultralytics import YOLO

model = YOLO('yolov8l.pt')

# %%
results = model("images/santander/logo_santander.png", save=True)
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/santander/logo_santander.png: 384x640 1 frisbee, 663.0ms
# Speed: 3.8ms preprocess, 663.0ms inference, 96.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([29.], device='cuda:0')
# conf: tensor([0.6863], device='cuda:0')
# data: tensor([[ 20.3074,  73.8440, 100.9458, 114.2439,   0.6863,  29.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (168, 300)
# shape: torch.Size([1, 6])
# xywh: tensor([[60.6266, 94.0440, 80.6384, 40.3999]], device='cuda:0')
# xywhn: tensor([[0.2021, 0.5598, 0.2688, 0.2405]], device='cuda:0')
# xyxy: tensor([[ 20.3074,  73.8440, 100.9458, 114.2439]], device='cuda:0')
# xyxyn: tensor([[0.0677, 0.4395, 0.3365, 0.6800]], device='cuda:0')
