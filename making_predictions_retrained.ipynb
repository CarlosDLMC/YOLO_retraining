# %%
import torch

print(f"Is the GPU available? {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
used_device = torch.cuda.current_device()
print(f"Used device: {used_device}")
print(f"Used device name: {torch.cuda.get_device_name(used_device)}")
# Out:
# Is the GPU available? True
# Device count: 2
# Used device: 0
# Used device name: AMD Radeon RX 6700 XT

# %%
from ultralytics import YOLO

PROJECT_DIR = "/home/mentefria/Documents/YOLO_retraining"

model = YOLO(f"{PROJECT_DIR}/models/best_20_ep_dtv_2.pt")

# %%
results = model(f"{PROJECT_DIR}/images/test_images/logo_santander.png")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/test_images/logo_santander.png: 384x640 2 santanders, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
from PIL import Image

# %%
im_array = results[0].plot()
im = Image.fromarray(im_array[..., ::-1])
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
def print_predictions_for_image(model, image_path):
    results = model(image_path)
    im_array = results[0].plot()
    im = Image.fromarray(im_array[..., ::-1])
    display(im)

# %%
print_predictions_for_image(model, f"{PROJECT_DIR}/images/test_images/teslas.jpg")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/test_images/teslas.jpg: 384x640 5 teslas, 18.8ms
# Speed: 1.2ms preprocess, 18.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
print_predictions_for_image(model, f"{PROJECT_DIR}/images/test_images/mi_correo.jpg")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/test_images/mi_correo.jpg: 448x640 1 santander, 20.3ms
# Speed: 1.7ms preprocess, 20.3ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=652x447>

# %%
print_predictions_for_image(model, f"{PROJECT_DIR}/images/test_images/logo_santander.png")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/test_images/logo_santander.png: 384x640 2 santanders, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
print_predictions_for_image(model, f"{PROJECT_DIR}/images/test_images/tesla_maletero.jpeg")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/test_images/tesla_maletero.jpeg: 448x640 1 tesla, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
print_predictions_for_image(model, f"{PROJECT_DIR}/images/santander/santander_banco_normal.jpeg")
# Out:
# image 1/1 /home/mentefria/Documents/YOLO_retraining/images/santander/santander_banco_normal.jpeg: 352x640 6 santanders, 444.3ms
# Speed: 1.8ms preprocess, 444.3ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=1200x630>
